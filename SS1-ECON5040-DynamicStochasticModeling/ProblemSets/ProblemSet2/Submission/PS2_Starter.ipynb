# %% [markdown]
# # Economics 5040 - Week 2
# ## Starter Notebook
#
# Expected Utility and Asset Pricing

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import matrix_rank, lstsq

# %% [markdown]
# # Problem 1. CARA Utility and the Price of Risk
#
# Write your derivations and economic explanations in Markdown cells.

# %%
gamma = 1/1000
w0 = 30000.0

def cara(w, gamma):
    # TODO
    pass

def ARA_cara(w, gamma):
    # TODO
    pass

def RRA_cara(w, gamma):
    # TODO
    pass

# TODO: plots, small gamble, certainty equivalent, risk premium, Devil's Offer

# %% [markdown]
# # Problem 2. From Outcomes to Expected Utility
#
# Write your derivations and economic explanations in Markdown cells.

# %%
x = np.array([25.0, 100.0, 225.0])
L = np.array([0.25, 0.50, 0.25])

# TODO: normalized utility, reduction to best-worst lottery,
# affine transformation, and non-affine counterexample

# %% [markdown]
# # Problem 3. State Prices and Arrow Securities
#
# Write your derivations and economic explanations in Markdown cells.

# %%
beta = 0.96
pi = np.array([0.5, 0.5])
c0 = 10.0
c1 = np.array([15.0, 5.0])  # H, L

# TODO: state prices, comparative statics, SDF

# %% [markdown]
# # Problem 4. Assets as Bundles of State-Contingent Claims
#
# Write your derivations and economic explanations in Markdown cells.

# %%
assets = {
    "A": np.array([1.0, 1.0]),
    "B": np.array([2.0, 0.0]),
    "C": np.array([0.0, 2.0]),
    "D": np.array([3.0, 1.0]),
}

# TODO: prices, returns, expected returns, pricing identities

# %% [markdown]
# # Problem 5. What Kind of Risk Commands a Premium?
#
# Write your derivations and economic explanations in Markdown cells.

# %%
# TODO: covariance risk premia and construct E and F

# %% [markdown]
# # Problem 6. Complete and Incomplete Markets
#
# Write your derivations and economic explanations in Markdown cells.

# %%
I = np.eye(3)
bond = np.array([1.0, 1.0, 1.0])
asset = np.array([2.0, 1.0, 0.0])
target = np.array([0.0, 1.0, 0.0])

# TODO: rank, replication, least squares, attainable payoff restriction

# %% [markdown]
# # Problem 7. Synthesis
#
# Write your synthesis and **What surprised me?** response here.
