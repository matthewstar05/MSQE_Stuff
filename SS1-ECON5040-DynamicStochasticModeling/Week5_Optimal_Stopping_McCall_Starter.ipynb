# %% [markdown]
# # Week 5 Problem Set: Optimal Stopping and the McCall Job Search Model
#
# ## Learning objectives
#
# By the end of this problem set, you should be able to:
#
# - Recognize an **optimal-stopping problem**.
# - Write a Bellman equation when the choice is **stop or continue**.
# - Understand why dynamic programming does **not** require an explicit discount factor.
# - Derive and interpret a cutoff policy.
# - Solve the McCall job-search model using value-function iteration.
# - Interpret the reservation wage.
# - Analyze how the value of waiting affects optimal stopping.
#
# Throughout the notebook, explain the economics as well as doing the calculations.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Problem 1. The Parking Problem: A Simple Optimal-Stopping Model
#
# You are driving down a one-way street toward your office. Parking spaces occur at regular intervals.
#
# Your office is next to the best possible parking space. Parking there gives a loss of \(0\). Parking one space away gives a loss of \(1\), parking two spaces away gives a loss of \(2\), and so forth.
#
# You can see only the parking space you are currently passing. Each parking space is independently open with probability
#
# \[
# 0<p<1.
# \]
#
# When you encounter an open parking space, you must decide immediately whether to park or continue. Once you pass a space, you cannot return to it.
#
# If you pass your office without finding a parking space, you continue down the street and park in the first available space.

# %% [markdown]
# ### 1(a) Why is this an optimal-stopping problem?
#
# What are the two possible actions when you encounter an open space? What does **stop** mean? What does **continue** mean? Why is rejecting an open parking space irreversible?
#
# **Your answer:**

# %% [markdown]
# ### 1(b) A useful infinite sum
#
# Consider
#
# \[
# S=p+2p^2+3p^3+4p^4+\cdots.
# \]
#
# Show that
#
# \[
# S=\frac{p}{(1-p)^2}.
# \]
#
# **Hint.** Multiply \(S\) by \(p\):
#
# \[
# pS=p^2+2p^3+3p^4+\cdots
# \]
#
# and subtract \(pS\) from \(S\). What familiar geometric series remains?
#
# **Your derivation:**

# %% [markdown]
# ### 1(c) Expected loss after passing the office
#
# Suppose the office parking space is occupied. You will now take the first open space.
#
# Let \(q=1-p\). Show that the probabilities that the first available space is 1, 2, 3, ... spaces beyond the office are
#
# \[
# p,\quad qp,\quad q^2p,\quad\ldots
# \]
#
# so expected loss is
#
# \[
# p+2qp+3q^2p+4q^3p+\cdots.
# \]
#
# Use part (b), with \(q\) replacing \(p\), to show that this equals \(1/p\).
#
# What happens as \(p\to0\)? As \(p\to1\)?
#
# **Your answer:**

# %% [markdown]
# ### 1(d) The value at the office
#
# Let \(V(0)\) be expected loss immediately before observing whether the office space is open.
#
# Show that
#
# \[
# V(0)=\frac{1-p}{p}.
# \]
#
# **Your derivation:**

# %% [markdown]
# ### 1(e) The Bellman equation
#
# Suppose you are \(n\) spaces before the office. Let \(V(n)\) be expected loss **before** observing whether the current space is open.
#
# Show that
#
# \[
# V(n)
# =
# p\min\{n,V(n-1)\}
# +
# (1-p)V(n-1).
# \]
#
# Explain every term. Why is there no discount factor?
#
# **Your answer:**

# %% [markdown]
# ### 1(f) The stopping rule
#
# If the current space is open, show that you park if
#
# \[
# n\leq V(n-1),
# \]
#
# and continue if
#
# \[
# n>V(n-1).
# \]
#
# Why should the solution have a cutoff form?
#
# **Your answer:**

# %% [markdown]
# ### 1(g) Find the cutoff
#
# Show that the stopping condition can ultimately be written
#
# \[
# (1-p)^n\geq \frac12.
# \]
#
# Hence the real-valued cutoff is
#
# \[
# n^*(p)=\frac{\log(1/2)}{\log(1-p)}.
# \]
#
# Convert this into an integer parking rule and calculate the cutoff for
#
# \[
# p=0.10,\quad 0.20,\quad 0.50,\quad 0.80.
# \]
#
# Use Python to check your calculations.

# %%
# Complete the cutoff calculation.

p_values = np.array([0.10, 0.20, 0.50, 0.80])

# real_cutoff = ...
# integer_cutoff = ...

# for p, x, n in zip(p_values, real_cutoff, integer_cutoff):
#     print(f"p={p:.2f}: real cutoff={x:.4f}, integer cutoff={n}")

# %% [markdown]
# ### 1(h) Dynamic programming without discounting
#
# There is no \(\beta\) in the parking problem.
#
# Explain why this is nevertheless a dynamic programming problem. Distinguish between:
#
# 1. discounting future outcomes; and
# 2. making a current decision that changes the state and future opportunities.
#
# What role does \(1-p\) play in the recursion? Why is it **not** a discount factor?
#
# **Your answer:**

# %% [markdown]
# # Problem 2. The McCall Job Search Model
#
# An unemployed worker receives one wage offer each period. Possible wages are
#
# \[
# w_i=10,10.5,11,\ldots,60,
# \]
#
# and every wage is equally likely.
#
# Unemployment compensation is
#
# \[
# c=12,
# \]
#
# and the discount factor is
#
# \[
# \beta=0.95.
# \]
#
# An accepted job lasts forever.

# %% [markdown]
# ### 2(a) Stop or continue
#
# Why is McCall also an optimal-stopping problem?
#
# What corresponds to **parking**? What corresponds to **continuing**?
#
# Show that accepting wage \(w\) has value
#
# \[
# A(w)=\frac{w}{1-\beta},
# \]
#
# while rejecting has value
#
# \[
# C=c+\beta E[V(W')].
# \]
#
# Why does \(C\) not depend on the current wage?
#
# **Your answer:**

# %% [markdown]
# ### 2(b) Bellman equation
#
# Show that
#
# \[
# V(w)=\max\{A(w),C\}.
# \]
#
# Explain the two alternatives economically.
#
# **Your answer:**

# %% [markdown]
# ### 2(c) Reservation wage
#
# Show that there is a reservation wage \(\bar w\) such that
#
# \[
# w\geq\bar w \Rightarrow \text{accept},
# \qquad
# w<\bar w \Rightarrow \text{reject}.
# \]
#
# Using indifference at the cutoff, show that
#
# \[
# \bar w=(1-\beta)C.
# \]
#
# Compare this cutoff rule with the parking rule.
#
# **Your answer:**

# %% [markdown]
# # Problem 3. Solve the McCall Model Numerically
#
# Construct the wage grid and solve
#
# \[
# V_{\text{new}}(w)
# =
# \max\left\{
# \frac{w}{1-\beta},
# c+\beta E[V(W)]
# \right\}
# \]
#
# by value-function iteration until
#
# \[
# \max_w|V_{\text{new}}(w)-V(w)|<10^{-10}.
# \]
#
# Report:
#
# 1. number of iterations,
# 2. continuation value \(C\),
# 3. reservation wage,
# 4. lowest wage on the grid that is accepted.

# %%
# Parameters
beta = 0.95
c = 12.0
w = np.arange(10.0, 60.0 + 0.5, 0.5)
prob = np.ones(len(w)) / len(w)
tol = 1e-10

# Initial guess
V = np.zeros_like(w)

# TODO: value-function iteration
# for it in range(...):
#     C = ...
#     accept_value = ...
#     V_new = ...
#     error = ...
#     ...

# %% [markdown]
# ### 3(d) Plot the solution
#
# Plot on the same graph:
#
# - \(V(w)\),
# - the value of accepting,
# - the continuation value,
# - the reservation wage.
#
# Explain the kink in \(V(w)\).

# %%
# TODO: create the plot.

# %% [markdown]
# # Problem 4. The Value of Waiting
#
# Answer each question **before** doing any numerical experiment.
#
# ### 4(a)
# Increase unemployment compensation \(c\). What happens to the continuation value and reservation wage? Explain.
#
# ### 4(b)
# Increase \(\beta\). What happens to the reservation wage? Why?
#
# ### 4(c)
# Change the wage-offer distribution so high wages are more likely. What happens to the value of rejecting today's offer and to the reservation wage?
#
# ### 4(d)
# Relate these comparative statics to the parking problem. What happens when \(p\) rises? What common principle connects the two models?
#
# **Your answers:**

# %% [markdown]
# # Problem 5. Solve McCall Using the Continuation Value
#
# Because
#
# \[
# V(w)=\max\left\{\frac{w}{1-\beta},C\right\},
# \]
#
# the entire problem can be reduced to the scalar fixed point
#
# \[
# C
# =
# c+\beta E\left[
# \max\left\{\frac{W}{1-\beta},C\right\}
# \right].
# \]
#
# ### 5(a)
# Derive this equation.
#
# ### 5(b)
# Iterate directly on \(C\).
#
# ### 5(c)
# Verify that this produces the same continuation value and reservation wage as Problem 3.
#
# ### 5(d)
# Which method is faster, and why can this problem be reduced to a one-dimensional fixed point?

# %%
# TODO: iterate directly on C.

# C = ...
# for it in range(...):
#     C_new = ...
#     ...

# %% [markdown]
# # Problem 6. Job Separation
#
# Now suppose an accepted job ends each period with probability \(\delta\).
#
# Let \(U\) denote the value of entering a period unemployed **before receiving the next wage offer**, and let \(E(w)\) denote the value of being employed at wage \(w\).
#
# ### 6(a)
# Write the value \(E(w)\). Remember that next period the worker remains employed with probability \(1-\delta\) and becomes unemployed with probability \(\delta\).
#
# ### 6(b)
# Write the unemployed worker's Bellman equations.
#
# ### 6(c)
# Does the optimal policy still have a reservation-wage form? Explain.
#
# ### 6(d)
# How should an increase in \(\delta\) affect the value of accepting a job and the reservation wage? Give the intuition before doing any numerical calculation.
#
# **Your answers:**

# %% [markdown]
# # Final Question: What Did the Parking Problem Teach Us?
#
# In a short paragraph, compare the parking problem with McCall.
#
# Both have a decision of the form
#
# \[
# \text{STOP versus CONTINUE}.
# \]
#
# McCall has an explicit discount factor \(\beta\); the parking problem does not.
#
# Discuss:
#
# > **Dynamic programming is not fundamentally about discounting. It is about making decisions today when today's choice affects the opportunities available tomorrow.**
#
# **Your answer:**
